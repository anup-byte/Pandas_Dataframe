# %%
import pandas as pd
import numpy as np

# %%
nutrition = pd.read_csv("nutrition.csv", index_col=[0])

# %%
nutrition.set_index('name', inplace=True)

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %% [markdown]
# The get_loc() Method

# %%
"vitamin_k", 3

# %%
# column_label : 'vitamin_k'
# index position : 3

# %%
# Approach 1 - get label from position

# %%
nutrition.index
# Out:
# Index(['Cornstarch', 'Nuts, pecans', 'Eggplant, raw', 'Teff, uncooked',
#        'Sherbet, orange', 'Cauliflower, raw', 'Taro leaves, raw',
#        'Lamb, raw, ground', 'Cheese, camembert', 'Vegetarian fillets',
#        ...
#        'Beef, braised, cooked, all grades, trimmed to 1/8" fat, separable lean and fat, flat half, brisket',
#        'Beef, raw, select, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast',
#        'Beef, raw, choice, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast',
#        'Oil, uses similar to 95 degree hard butter, confection fat, palm kernel (hydrogenated), industrial',
#        'Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round steak, round',
#        'Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round',
# ...

# %%
nutrition.index[2]
# Out:
# 'Eggplant, raw'

# %%
index_label = nutrition.index[2]

# %%
nutrition.columns
# Out:
# Index(['serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol',
#        'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
column_label = 'vitamin_k'

# %%
nutrition.loc[index_label, column_label]
# Out:
# '3.5 mcg'

# %%
nutrition.at[index_label, column_label]
# Out:
# '3.5 mcg'

# %%
# Approach 2 - get integer location from label

# %%
nutrition.columns
# Out:
# Index(['serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol',
#        'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
nutrition.columns.get_loc('vitamin_k')
# Out:
# 26

# %%
index_loc = 2

# %%
columns_loc = 26

# %%
nutrition.iloc[index_loc, columns_loc]
# Out:
# '3.5 mcg'

# %%
nutrition.iat[index_loc, columns_loc]
# Out:
# '3.5 mcg'

# %% [markdown]
# Skill Challenge

# %% [markdown]
# Q1. Randomly select 10 food items and assign the resulting dataframe to a new variable called nutri_mini.

# %% [markdown]
# Q2. From nutri_mini, extract the total_fat and cholesterol columns for all rows.

# %% [markdown]
# Q3. Extract all the columns from vitamin_b12 to the end, for the first, second and third rows.

# %% [markdown]
# Q4. Get the calories for the third food in nutr_mini using an attribute-based approach that
# is faster than .loc or .iloc

# %%
nutrition.sample(10)
# Out:
#                                                    serving_size  calories  \
# name
# Beverages, Ready-to-Drink, Nutritional Shake, E...        100 g       105
# Potatoes, unprepared, frozen, salt not added in...        100 g       138
# Turkey bacon, unprepared                                  100 g       226
# Beef, braised, cooked, select, trimmed to 0" fa...        100 g       198
# Fish, raw, mixed species, Pacific, rockfish               100 g        90
# Infant formula, ready-to-feed, with iron, GOOD ...        100 g        65
# USDA Commodity, with broth, meat only, canned, ...        100 g       133
# SILK Key Lime soy yogurt                                  100 g        88
# Cereals ready-to-eat, RALSTON Corn Flakes                 100 g       357
# Pork loin, lean only, raw, bone-in, backribs, f...        100 g       172
#
#                                                    total_fat saturated_fat  \
# name
# ...

# %%
nutri_mini = nutrition.sample(10)

# %%
nutri_mini.shape
# Out:
# (10, 75)

# %%
nutri_mini.loc[:, ['total_fat', 'cholesterol']]
# Out:
#                                                    total_fat cholesterol
# name
# Cereals, dry, 10 minute cooking, regular, CREAM...      1.5g           0
# Chicken, roasted, cooked, with added solution, ...        5g       124mg
# Beverages, added vitamin C, with low-calorie sw...        0g           0
# Gravy, au jus, CAMPBELL'S                                 0g           0
# Lamb, roasted, cooked, trimmed to 1/8" fat, sep...      6.7g       111mg
# Cowpeas (blackeyes), unprepared, frozen, immatu...      0.7g           0
# Babyfood, strained, peas, vegetables                    0.4g           0
# Beef, roasted, cooked, all grades, trimmed to 1...       23g        82mg
# Lamb, raw, trimmed to 1/8" fat, separable lean ...      4.9g        64mg
# Rice and vermicelli mix, unprepared, rice pilaf...      1.4g         1mg

# %%
nutri_mini.columns.get_loc('vitamin_b12')
# Out:
# 20

# %%
nutri_mini.iloc[0:3, 20:]
# Out:
#                                                    vitamin_b12 vitamin_b6  \
# name
# Cereals, dry, 10 minute cooking, regular, CREAM...    0.00 mcg   0.108 mg
# Chicken, roasted, cooked, with added solution, ...    0.41 mcg   0.413 mg
# Beverages, added vitamin C, with low-calorie sw...    0.00 mcg   0.004 mg
#
#                                                    vitamin_c vitamin_d  \
# name
# Cereals, dry, 10 minute cooking, regular, CREAM...    0.0 mg   0.00 IU
# Chicken, roasted, cooked, with added solution, ...    0.0 mg   6.00 IU
# Beverages, added vitamin C, with low-calorie sw...   25.1 mg   0.00 IU
#
#                                                    vitamin_e tocopherol_alpha  \
# name
# Cereals, dry, 10 minute cooking, regular, CREAM...   0.11 mg          0.11 mg
# Chicken, roasted, cooked, with added solution, ...   0.23 mg          0.23 mg
# Beverages, added vitamin C, with low-calorie sw...   1.13 mg          1.13 mg
#
# ...

# %%
nutri_mini.iat[2, 1]
# Out:
# 4
