# %% [markdown]
# Collecting the Units

# %%
import pandas as pd
import numpy as np

# %%
nutrition = pd.read_csv("nutrition.csv", index_col=[0])

# %%
nutrition.set_index('name', inplace=True)

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
#                      fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch        0.05 g               0.009 g                     0.016 g
# Nuts, pecans     71.97 g               6.180 g                    40.801 g
# Eggplant, raw     0.18 g               0.034 g                     0.016 g
# Teff, uncooked    2.38 g               0.449 g                     0.589 g
# Sherbet, orange   2.00 g               1.160 g                     0.530 g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                          0.025 g                 0.00 mg   0.0 g
# Nuts, pecans                       21.614 g                 0.00 mg   0.0 g
# Eggplant, raw                       0.076 g                 0.00 mg   0.0 g
# Teff, uncooked                      1.071 g                       0       0
# Sherbet, orange                     0.080 g                 1.00 mg   0.0 g
#
#                     ash caffeine theobromine    water
# name
# Cornstarch       0.09 g  0.00 mg     0.00 mg   8.32 g
# Nuts, pecans     1.49 g  0.00 mg     0.00 mg   3.52 g
# Eggplant, raw    0.66 g  0.00 mg     0.00 mg  92.30 g
# Teff, uncooked   2.37 g        0           0   8.82 g
# Sherbet, orange  0.40 g  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 75 columns]

# %%
nutrition.replace('', '', regex=True)

# %%
nutrition.sample(20, axis=1).head()
# Out:
#                 histidine hydroxyproline   serine vitamin_a  fiber glucose  \
# name
# Cornstarch        0.008 g              0  0.012 g   0.00 IU  0.9 g       0
# Nuts, pecans      0.262 g              0  0.474 g  56.00 IU  9.6 g  0.04 g
# Eggplant, raw     0.023 g              0  0.042 g  23.00 IU  3.0 g  1.58 g
# Teff, uncooked    0.301 g              0  0.622 g   9.00 IU  8.0 g  0.73 g
# Sherbet, orange         0              0        0  46.00 IU  1.3 g       0
#
#                 aspartic_acid vitamin_b12  lucopene phenylalanine total_fat  \
# name
# Cornstarch            0.020 g    0.00 mcg         0       0.013 g      0.1g
# Nuts, pecans          0.929 g    0.00 mcg         0       0.426 g       72g
# Eggplant, raw         0.164 g    0.00 mcg         0       0.043 g      0.2g
# Teff, uncooked        0.820 g           0         0       0.698 g      2.4g
# Sherbet, orange             0    0.13 mcg         0             0        2g
#
#                 carbohydrate carotene_alpha vitamin_d theobromine     zink  \
# name
# Cornstarch           91.27 g       0.00 mcg   0.00 IU     0.00 mg  0.06 mg
# Nuts, pecans         13.86 g       0.00 mcg   0.00 IU     0.00 mg  4.53 mg
# Eggplant, raw         5.88 g       0.00 mcg   0.00 IU     0.00 mg  0.16 mg
# Teff, uncooked       73.13 g       0.00 mcg         0           0  3.63 mg
# Sherbet, orange      30.40 g       0.00 mcg   0.00 IU     0.00 mg  0.48 mg
#
#                  proline   sugars  magnesium tryptophan
# name
# Cornstarch       0.024 g   0.00 g    3.00 mg    0.001 g
# Nuts, pecans     0.363 g   3.97 g  121.00 mg    0.093 g
# Eggplant, raw    0.043 g   3.53 g   14.00 mg    0.009 g
# Teff, uncooked   0.664 g   1.84 g  184.00 mg    0.139 g
# Sherbet, orange        0  24.32 g    8.00 mg          0

# %%
0.008 g
14.00 mg
2.4g
0.00 IU	
0.13 mcg

# %%
nutrition.replace('[^a-zA-Z]', '', regex=True)
# Out:
#                                                    serving_size  calories  \
# name
# Cornstarch                                                    g       381
# Nuts, pecans                                                  g       691
# Eggplant, raw                                                 g        25
# Teff, uncooked                                                g       367
# Sherbet, orange                                               g       144
# ...                                                         ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...            g       125
# Lamb, cooked, separable lean only, composite of...            g       206
# Lamb, raw, separable lean and fat, composite of...            g       277
# Beef, raw, all grades, trimmed to 0" fat, separ...            g       121
# Beef, raw, all grades, trimmed to 0" fat, separ...            g       121
#
#                                                    total_fat saturated_fat  \
# name
# Cornstarch                                                 g           NaN
# Nuts, pecans                                               g             g
# Eggplant, raw                                              g           NaN
# Teff, uncooked                                             g             g
# Sherbet, orange                                            g             g
# ...                                                      ...           ...
# Beef, raw, all grades, trimmed to 0" fat, separ...         g             g
# Lamb, cooked, separable lean only, composite of...         g             g
# Lamb, raw, separable lean and fat, composite of...         g             g
# Beef, raw, all grades, trimmed to 0" fat, separ...         g             g
# Beef, raw, all grades, trimmed to 0" fat, separ...         g             g
#
#                                                    cholesterol sodium choline  \
# name
# Cornstarch                                                         mg      mg
# Nuts, pecans                                                       mg      mg
# Eggplant, raw                                                      mg      mg
# Teff, uncooked                                                     mg      mg
# Sherbet, orange                                             mg     mg      mg
# ...                                                        ...    ...     ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     mg      mg
# Lamb, cooked, separable lean only, composite of...          mg     mg
# Lamb, raw, separable lean and fat, composite of...          mg     mg
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     mg      mg
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     mg      mg
#
#                                                    folate folic_acid niacin  \
# name
# Cornstarch                                            mcg        mcg     mg
# Nuts, pecans                                          mcg        mcg     mg
# Eggplant, raw                                         mcg        mcg     mg
# Teff, uncooked                                                           mg
# Sherbet, orange                                       mcg        mcg     mg
# ...                                                   ...        ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...    mcg        mcg     mg
# Lamb, cooked, separable lean only, composite of...    mcg        mcg     mg
# Lamb, raw, separable lean and fat, composite of...    mcg        mcg     mg
# Beef, raw, all grades, trimmed to 0" fat, separ...    mcg        mcg     mg
# Beef, raw, all grades, trimmed to 0" fat, separ...    mcg        mcg     mg
#
#                                                     ... fat  \
# name                                                ...
# Cornstarch                                          ...   g
# Nuts, pecans                                        ...   g
# Eggplant, raw                                       ...   g
# Teff, uncooked                                      ...   g
# Sherbet, orange                                     ...   g
# ...                                                 ...  ..
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   g
# Lamb, cooked, separable lean only, composite of...  ...   g
# Lamb, raw, separable lean and fat, composite of...  ...   g
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   g
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   g
#
#                                                    saturated_fatty_acids  \
# name
# Cornstarch                                                             g
# Nuts, pecans                                                           g
# Eggplant, raw                                                          g
# Teff, uncooked                                                         g
# Sherbet, orange                                                        g
# ...                                                                  ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                     g
# Lamb, cooked, separable lean only, composite of...                     g
# Lamb, raw, separable lean and fat, composite of...                     g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     g
#
#                                                    monounsaturated_fatty_acids  \
# name
# Cornstarch                                                                   g
# Nuts, pecans                                                                 g
# Eggplant, raw                                                                g
# Teff, uncooked                                                               g
# Sherbet, orange                                                              g
# ...                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Lamb, cooked, separable lean only, composite of...                           g
# Lamb, raw, separable lean and fat, composite of...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Cornstarch                                                                   g
# Nuts, pecans                                                                 g
# Eggplant, raw                                                                g
# Teff, uncooked                                                               g
# Sherbet, orange                                                              g
# ...                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Lamb, cooked, separable lean only, composite of...                           g
# Lamb, raw, separable lean and fat, composite of...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
#
#                                                    fatty_acids_total_trans  \
# name
# Cornstarch                                                              mg
# Nuts, pecans                                                            mg
# Eggplant, raw                                                           mg
# Teff, uncooked
# Sherbet, orange                                                         mg
# ...                                                                    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                      mg
# Lamb, cooked, separable lean only, composite of...                      mg
# Lamb, raw, separable lean and fat, composite of...                      mg
# Beef, raw, all grades, trimmed to 0" fat, separ...                      mg
# Beef, raw, all grades, trimmed to 0" fat, separ...                      mg
#
#                                                    alcohol ash caffeine  \
# name
# Cornstarch                                               g   g       mg
# Nuts, pecans                                             g   g       mg
# Eggplant, raw                                            g   g       mg
# Teff, uncooked                                               g
# Sherbet, orange                                          g   g       mg
# ...                                                    ...  ..      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...       g   g       mg
# Lamb, cooked, separable lean only, composite of...           g
# Lamb, raw, separable lean and fat, composite of...           g
# Beef, raw, all grades, trimmed to 0" fat, separ...       g   g       mg
# Beef, raw, all grades, trimmed to 0" fat, separ...       g   g       mg
#
#                                                    theobromine  water
# name
# Cornstarch                                                  mg      g
# Nuts, pecans                                                mg      g
# Eggplant, raw                                               mg      g
# Teff, uncooked                                                      g
# Sherbet, orange                                             mg      g
# ...                                                        ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg      g
# Lamb, cooked, separable lean only, composite of...                  g
# Lamb, raw, separable lean and fat, composite of...                  g
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg      g
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg      g
#
# [8789 rows x 75 columns]

# %%
nutrition.astype(str).replace('[^a-zA-Z]', '', regex=True)
# Out:
#                                                    serving_size calories  \
# name
# Cornstarch                                                    g
# Nuts, pecans                                                  g
# Eggplant, raw                                                 g
# Teff, uncooked                                                g
# Sherbet, orange                                               g
# ...                                                         ...      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
# Lamb, cooked, separable lean only, composite of...            g
# Lamb, raw, separable lean and fat, composite of...            g
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
#
#                                                    total_fat saturated_fat  \
# name
# Cornstarch                                                 g           nan
# Nuts, pecans                                               g             g
# Eggplant, raw                                              g           nan
# Teff, uncooked                                             g             g
# Sherbet, orange                                            g             g
# ...                                                      ...           ...
# Beef, raw, all grades, trimmed to 0" fat, separ...         g             g
# Lamb, cooked, separable lean only, composite of...         g             g
# Lamb, raw, separable lean and fat, composite of...         g             g
# Beef, raw, all grades, trimmed to 0" fat, separ...         g             g
# Beef, raw, all grades, trimmed to 0" fat, separ...         g             g
#
#                                                    cholesterol sodium choline  \
# name
# Cornstarch                                                         mg      mg
# Nuts, pecans                                                       mg      mg
# Eggplant, raw                                                      mg      mg
# Teff, uncooked                                                     mg      mg
# Sherbet, orange                                             mg     mg      mg
# ...                                                        ...    ...     ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     mg      mg
# Lamb, cooked, separable lean only, composite of...          mg     mg
# Lamb, raw, separable lean and fat, composite of...          mg     mg
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     mg      mg
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     mg      mg
#
#                                                    folate folic_acid niacin  \
# name
# Cornstarch                                            mcg        mcg     mg
# Nuts, pecans                                          mcg        mcg     mg
# Eggplant, raw                                         mcg        mcg     mg
# Teff, uncooked                                                           mg
# Sherbet, orange                                       mcg        mcg     mg
# ...                                                   ...        ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...    mcg        mcg     mg
# Lamb, cooked, separable lean only, composite of...    mcg        mcg     mg
# Lamb, raw, separable lean and fat, composite of...    mcg        mcg     mg
# Beef, raw, all grades, trimmed to 0" fat, separ...    mcg        mcg     mg
# Beef, raw, all grades, trimmed to 0" fat, separ...    mcg        mcg     mg
#
#                                                     ... fat  \
# name                                                ...
# Cornstarch                                          ...   g
# Nuts, pecans                                        ...   g
# Eggplant, raw                                       ...   g
# Teff, uncooked                                      ...   g
# Sherbet, orange                                     ...   g
# ...                                                 ...  ..
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   g
# Lamb, cooked, separable lean only, composite of...  ...   g
# Lamb, raw, separable lean and fat, composite of...  ...   g
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   g
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   g
#
#                                                    saturated_fatty_acids  \
# name
# Cornstarch                                                             g
# Nuts, pecans                                                           g
# Eggplant, raw                                                          g
# Teff, uncooked                                                         g
# Sherbet, orange                                                        g
# ...                                                                  ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                     g
# Lamb, cooked, separable lean only, composite of...                     g
# Lamb, raw, separable lean and fat, composite of...                     g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     g
# Beef, raw, all grades, trimmed to 0" fat, separ...                     g
#
#                                                    monounsaturated_fatty_acids  \
# name
# Cornstarch                                                                   g
# Nuts, pecans                                                                 g
# Eggplant, raw                                                                g
# Teff, uncooked                                                               g
# Sherbet, orange                                                              g
# ...                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Lamb, cooked, separable lean only, composite of...                           g
# Lamb, raw, separable lean and fat, composite of...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Cornstarch                                                                   g
# Nuts, pecans                                                                 g
# Eggplant, raw                                                                g
# Teff, uncooked                                                               g
# Sherbet, orange                                                              g
# ...                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Lamb, cooked, separable lean only, composite of...                           g
# Lamb, raw, separable lean and fat, composite of...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
# Beef, raw, all grades, trimmed to 0" fat, separ...                           g
#
#                                                    fatty_acids_total_trans  \
# name
# Cornstarch                                                              mg
# Nuts, pecans                                                            mg
# Eggplant, raw                                                           mg
# Teff, uncooked
# Sherbet, orange                                                         mg
# ...                                                                    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                      mg
# Lamb, cooked, separable lean only, composite of...                      mg
# Lamb, raw, separable lean and fat, composite of...                      mg
# Beef, raw, all grades, trimmed to 0" fat, separ...                      mg
# Beef, raw, all grades, trimmed to 0" fat, separ...                      mg
#
#                                                    alcohol ash caffeine  \
# name
# Cornstarch                                               g   g       mg
# Nuts, pecans                                             g   g       mg
# Eggplant, raw                                            g   g       mg
# Teff, uncooked                                               g
# Sherbet, orange                                          g   g       mg
# ...                                                    ...  ..      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...       g   g       mg
# Lamb, cooked, separable lean only, composite of...           g
# Lamb, raw, separable lean and fat, composite of...           g
# Beef, raw, all grades, trimmed to 0" fat, separ...       g   g       mg
# Beef, raw, all grades, trimmed to 0" fat, separ...       g   g       mg
#
#                                                    theobromine water
# name
# Cornstarch                                                  mg     g
# Nuts, pecans                                                mg     g
# Eggplant, raw                                               mg     g
# Teff, uncooked                                                     g
# Sherbet, orange                                             mg     g
# ...                                                        ...   ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     g
# Lamb, cooked, separable lean only, composite of...                 g
# Lamb, raw, separable lean and fat, composite of...                 g
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     g
# Beef, raw, all grades, trimmed to 0" fat, separ...          mg     g
#
# [8789 rows x 75 columns]

# %%
units = nutrition.astype(str).replace('[^a-zA-Z]', '', regex=True)

# %%
units.head()
# Out:
#                 serving_size calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch                 g                  g           nan
# Nuts, pecans               g                  g             g
# Eggplant, raw              g                  g           nan
# Teff, uncooked             g                  g             g
# Sherbet, orange            g                  g             g          mg
#
#                 sodium choline folate folic_acid niacin  ... fat  \
# name                                                     ...
# Cornstarch          mg      mg    mcg        mcg     mg  ...   g
# Nuts, pecans        mg      mg    mcg        mcg     mg  ...   g
# Eggplant, raw       mg      mg    mcg        mcg     mg  ...   g
# Teff, uncooked      mg      mg                       mg  ...   g
# Sherbet, orange     mg      mg    mcg        mcg     mg  ...   g
#
#                 saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                          g                           g
# Nuts, pecans                        g                           g
# Eggplant, raw                       g                           g
# Teff, uncooked                      g                           g
# Sherbet, orange                     g                           g
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                                g                      mg       g
# Nuts, pecans                              g                      mg       g
# Eggplant, raw                             g                      mg       g
# Teff, uncooked                            g
# Sherbet, orange                           g                      mg       g
#
#                 ash caffeine theobromine water
# name
# Cornstarch        g       mg          mg     g
# Nuts, pecans      g       mg          mg     g
# Eggplant, raw     g       mg          mg     g
# Teff, uncooked    g                          g
# Sherbet, orange   g       mg          mg     g
#
# [5 rows x 75 columns]

# %%
units.saturated_fat
# Out:
# name
# Cornstarch                                                                                            nan
# Nuts, pecans                                                                                            g
# Eggplant, raw                                                                                         nan
# Teff, uncooked                                                                                          g
# Sherbet, orange                                                                                         g
#                                                                                                      ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round      g
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand      g
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand      g
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round      g
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round      g
# Name: saturated_fat, Length: 8789, dtype: object

# %%
units.saturated_fat.value_counts()
# Out:
# saturated_fat
# g      7199
# nan    1590
# Name: count, dtype: int64

# %%
units.saturated_fat.mode()
# Out:
# 0    g
# Name: saturated_fat, dtype: object

# %%
units.mode()
# Out:
#   serving_size calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g                  g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 75 columns]

# %%
units = units.mode()
