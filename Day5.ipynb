# %%
import pandas as pd
import numpy as np

# %%
nutrition = pd.read_csv("nutrition.csv")

# %%
nutrition.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
nutrition = pd.read_csv("nutrition.csv", index_col=[0])

# %%
nutrition.head()
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
nutrition.shape
# Out:
# (8789, 76)

# %%
nutrition.sample() # random record or observation
# Out:
#                                                    name serving_size  \
# 4569  Mushroom, raw, exposed to ultraviolet light, w...        100 g
#
#       calories total_fat saturated_fat cholesterol   sodium  choline  \
# 4569        22      0.3g          0.1g           0  5.00 mg  17.3 mg
#
#          folate folic_acid  ...     fat saturated_fatty_acids  \
# 4569  17.00 mcg   0.00 mcg  ...  0.34 g               0.050 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4569                     0.000 g                     0.160 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 4569                 0.00 mg   0.0 g  0.85 g  0.00 mg     0.00 mg  92.45 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample() # random record or observation
# Out:
#                                                    name serving_size  \
# 4736  Chicken, raw, meat only, wing, broilers or fryers        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# 4736       126      3.5g          0.9g        57mg  81.00 mg  65.8 mg
#
#         folate folic_acid  ...     fat saturated_fatty_acids  \
# 4736  4.00 mcg   0.00 mcg  ...  3.54 g               0.940 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4736                     0.850 g                     0.800 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 4736                57.00 mg   0.0 g  0.83 g  0.00 mg     0.00 mg  74.95 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample() # random record or observation
# Out:
#                                                    name serving_size  \
# 6024  Babyfood, junior, vegetables and dumplings and...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium choline  \
# 6024        48      0.8g           NaN           0  52.00 mg       0
#
#         folate folic_acid  ...     fat saturated_fatty_acids  \
# 6024  7.00 mcg   0.00 mcg  ...  0.80 g                     0
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 6024                           0                           0
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 6024                       0       0  0.60 g        0           0  88.60 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(random_state=12)
# Out:
#                                                  name serving_size  calories  \
# 3713  Thuringer, pork, beef, summer sausage, cervelat        100 g       362
#
#      total_fat saturated_fat cholesterol      sodium  choline    folate  \
# 3713       30g           12g        74mg  1300.00 mg  78.9 mg  2.00 mcg
#
#      folic_acid  ...      fat saturated_fatty_acids  \
# 3713   0.00 mcg  ...  30.43 g              11.510 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 3713                    12.970 g                     1.200 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 3713                74.00 mg   0.0 g  3.63 g  0.00 mg     0.00 mg  45.18 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(n=3)
# Out:
#                                                    name serving_size  \
# 2848       Turkey, seasoned, light and dark meat, diced        100 g
# 4772  Cereals, dry, peach almond, REAL MEDLEYS, oatm...        100 g
# 2098           KASHI, Frozen Entree, Tuscan Veggie Bake        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium choline  \
# 2848       138        6g          1.8g        55mg  850.00 mg       0
# 4772       387      9.8g          1.1g           0  201.00 mg       0
# 2098        90      3.2g          0.5g           0  245.00 mg       0
#
#          folate folic_acid  ...     fat saturated_fatty_acids  \
# 2848   5.00 mcg   0.00 mcg  ...  6.00 g               1.750 g
# 4772  27.00 mcg          0  ...  9.84 g               1.114 g
# 2098          0          0  ...  3.20 g               0.500 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 2848                     1.980 g                     1.530 g
# ...

# %%
nutrition.sample(frac=.01)
# Out:
#                                                    name serving_size  \
# 8718  Beef, roasted, cooked, select, trimmed to 0" f...        100 g
# 1099                          Dessert topping, powdered        100 g
# 3666    Candies, DOVE Milk Chocolate, MARS SNACKFOOD US        100 g
# 5439  Cereals ready-to-eat, KASHI 7 Whole Grain Hone...        100 g
# 2563               Cereals, cooked with water, WHEATENA        100 g
# ...                                                 ...          ...
# 3785     Vegetable juice, DAILY GREENS, BOLTHOUSE FARMS        100 g
# 6100  Soup, reduced sodium, condensed, canned, cream...        100 g
# 2843       Alcoholic Beverage, Claret, red, table, wine        100 g
# 3041         Fish, dry heat, cooked, greenland, halibut        100 g
# 3622    Rice, enriched, raw, regular, long-grain, white        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium   choline  \
# ...

# %%
nutrition.shape
# Out:
# (8789, 76)

# %%
8789 * .01
# Out:
# 87.89

# %%
nutrition.sample(frac=.01, n=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/anupjha/Desktop/Desk/AI KI PATHSHALA/Pandas_Live_session /Pandas_Dataframe/Day5.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/anupjha/Desktop/Desk/AI%20KI%20PATHSHALA/Pandas_Live_session%20/Pandas_Dataframe/Day5.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> nutrition.sample(frac=.01, n=10)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:6021, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6018 # Process random_state argument
#    6019 rs = common.random_state(random_state)
# -> 6021 size = sample.process_sampling_size(n, frac, replace)
#    6022 if size is None:
#    6023     assert frac is not None
#
# ...

# %% [markdown]
# Sampling with Replacements or Weights

# %%
nutrition.sample(n=3, replace=True)
# Out:
#                                                    name serving_size  \
# 2408              Collards, unprepared, chopped, frozen        100 g
# 6498  Beef, raw, separable lean and fat, cube roll, ...        100 g
# 7227  Soup, prepared with equal volume low fat (2%) ...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium  choline  \
# 2408        33      0.4g           NaN           0   48.00 mg        0
# 6498       225       16g          6.7g        60mg   43.00 mg        0
# 7227        61      3.2g          1.9g        10mg  354.00 mg  11.8 mg
#
#          folate folic_acid  ...      fat saturated_fatty_acids  \
# 2408  73.00 mcg   0.00 mcg  ...   0.37 g               0.048 g
# 6498          0          0  ...  16.31 g               6.734 g
# 7227   4.00 mcg   0.00 mcg  ...   3.23 g               1.930 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 2408                     0.027 g                     0.178 g
# ...

# %%
# weighted sampling

# %%
weight = pd.Series(data=[10, 10, 10, 1, 2], index = [7, 17, 29, 5, 6])

# %%
weight
# Out:
# 7     10
# 17    10
# 29    10
# 5      1
# 6      2
# dtype: int64

# %%
nutrition.sample(n=3, weights=weight)
# Out:
#                       name serving_size  calories total_fat saturated_fat  \
# 29  Nuts, dried, pine nuts        100 g       673       68g          4.9g
# 6         Taro leaves, raw        100 g        42      0.7g          0.2g
# 17  Peppers, raw, jalapeno        100 g        29      0.4g          0.1g
#
#    cholesterol   sodium  choline      folate folic_acid  ...      fat  \
# 29           0  2.00 mg  55.8 mg   34.00 mcg   0.00 mcg  ...  68.37 g
# 6            0  3.00 mg  12.8 mg  126.00 mcg   0.00 mcg  ...   0.74 g
# 17           0  3.00 mg   7.5 mg   27.00 mcg   0.00 mcg  ...   0.37 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 29               4.899 g                    18.764 g
# 6                0.151 g                     0.060 g
# 17               0.092 g                     0.029 g
#
#    polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 29                    34.071 g                 0.00 mg   0.0 g  2.59 g
# ...

# %%
nutrition.sample(n=3, weights=weight)
# Out:
#                       name serving_size  calories total_fat saturated_fat  \
# 17  Peppers, raw, jalapeno        100 g        29      0.4g          0.1g
# 7        Lamb, raw, ground        100 g       282       23g           10g
# 5         Cauliflower, raw        100 g        25      0.3g          0.1g
#
#    cholesterol    sodium  choline     folate folic_acid  ...      fat  \
# 17           0   3.00 mg   7.5 mg  27.00 mcg   0.00 mcg  ...   0.37 g
# 7         73mg  59.00 mg  69.3 mg  18.00 mcg   0.00 mcg  ...  23.41 g
# 5            0  30.00 mg  44.3 mg  57.00 mcg   0.00 mcg  ...   0.28 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 17               0.092 g                     0.029 g
# 7               10.190 g                     9.600 g
# 5                0.130 g                     0.034 g
#
#    polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 17                     0.112 g                 0.00 mg   0.0 g  0.53 g
# ...
