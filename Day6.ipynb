# %%
import pandas as pd
import numpy as np

# %%
nutrition = pd.read_csv("nutrition.csv", index_col=[0])

# %%
nutrition.head()
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %% [markdown]
# How Are Random Numbers Generated

# %%
nutrition.sample()
# Out:
#                                            name serving_size  calories  \
# 3254  Peanuts, with salt, oil-roasted, virginia        100 g       578
#
#      total_fat saturated_fat cholesterol     sodium choline      folate  \
# 3254       49g          6.3g           0  433.00 mg       0  125.00 mcg
#
#      folic_acid  ...      fat saturated_fatty_acids  \
# 3254   0.00 mcg  ...  48.62 g               6.345 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 3254                    25.222 g                    14.669 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine   water
# 3254                 0.00 mg       0  3.48 g        0           0  2.17 g
#
# [1 rows x 76 columns]

# %% [markdown]
# PRNGs(Pseudo Random Number Generator)
#
# Both Python and Pandas Via Numpy use a variation of Pseudo Random Number Generator Called Mersenne Twister.

# %%
nutrition.sample(random_state=19)
# Out:
#                                                    name serving_size  \
# 4176  Babyfood, apple and sweet potato, fruit and ve...        100 g
#
#       calories total_fat saturated_fat cholesterol   sodium choline    folate  \
# 4176        64      0.2g           NaN           0  3.00 mg  4.4 mg  2.00 mcg
#
#      folic_acid  ...     fat saturated_fatty_acids  \
# 4176   0.00 mcg  ...  0.22 g               0.041 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4176                     0.008 g                     0.079 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 4176                 0.00 mg   0.0 g  0.30 g  0.00 mg     0.00 mg  84.00 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(random_state=13)
# Out:
#                                                    name serving_size  \
# 4453  KFC, Skin and Breading, EXTRA CRISPY, Fried Ch...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium choline folate  \
# 4453       464       37g          7.5g        59mg  828.00 mg       0      0
#
#      folic_acid  ...      fat saturated_fatty_acids  \
# 4453          0  ...  36.61 g               7.541 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4453                    11.816 g                    14.238 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 4453                59.00 mg       0  2.92 g        0           0  26.98 g
#
# [1 rows x 76 columns]
